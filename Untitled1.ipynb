# %% [markdown]
# <a href="https://colab.research.google.com/github/Richa-Singh-Codes/LocalRepo/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files
uploaded = files.upload()

df = pd.read_csv('shopping_trends.csv')
print("Dataset loaded successfully.")
print(df.head())
# Out:
#      <input type="file" id="files-474c3e54-cfbb-4f39-8e8d-5a5faecb5cc8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-474c3e54-cfbb-4f39-8e8d-5a5faecb5cc8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print("Basic Information")
print(df.info())

print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")

print("Summary Statistics")
print(df.describe())

print("Missing Values")
print(df.isnull().sum())

print("Data Types")
print(df.dtypes)

print("Mean, Median, Mode of purchase amount")
print(f"Mean: ${df['Purchase amount (USD)'].mean():.2f}")
print(f"Median: ${df['Purchase amount (USD)'].median():.2f}")
print(f"Mode: ${df['Purchase amount (USD)'].mode()[0]:.2f}")
# Out:
# Basic Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
# Visualization-1 : Bar Chart
from pandas.core.indexes import category
plt.figure(figsize=(10,5))
category_sales = df.groupby('Category')['Purchase Amount (USD)'].sum().sort_values(ascending=False)
category_sales.plot(kind='bar', color='steelblue', edgecolor = 'black')
plt.title('Total purchase amount by product category', fontsize=14)
plt.xlabel('Category')
plt.ylabel('Total Sales (USD)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('chart1_bar.png', dpi=150)
plt.show()

# %%
# Visualization-2 : Line Chart

plt.figure(figsize=(10,5))
season_order = ['Spring', 'Summer', 'Fall', 'Winter']
season_sales = df.groupby('Season')['Purchase Amount (USD)'].mean().reindex(season_order)
season_sales.plot(kind='line', marker='o', color='darkorange', linewidth=2)
plt.title('Average purchase amount by season', fontsize=14)
plt.xlabel('Season')
plt.ylabel('Average purchase amount (USD)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig('chart2_line.png', dpi=150)
plt.show()

# %%
# Visualization-3 : Pie Chart

plt.figure(figsize=(7,7))
payment_counts = df['Payment Method'].value_counts()
plt.pie(payment_counts, labels=payment_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Customer payment method distribution', fontsize=14)
plt.tight_layout()
plt.savefig('chart3_pie.png', dpi=150)
plt.show()
